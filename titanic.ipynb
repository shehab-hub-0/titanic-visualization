# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data():
    data=pd.read_csv(r"C:\Users\a\Desktop\data_eng_project\assignment\Visualization\titanic\Titanic-Dataset.csv")
    data=data.drop(columns=["Cabin"])
    data["Age"]=data["Age"].fillna(data["Age"].mean())
    data["Embarked"]=data["Embarked"].fillna(data["Embarked"].mode()[0])
    data["Sex_numerical"]=data["Sex"].map({"male":0,"female":1})
    return data

# %%
data=load_data()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
sns.countplot(x='Survived',data=data)
plt.title("Survived VS NonSurvived")
plt.xlabel("0<--->Survived  | NonSurvived<--->1")
# Out:
# Text(0.5, 0, '0<--->Survived  | NonSurvived<--->1')

# %%
sns.countplot(data=data, x='Sex', hue='Survived')
plt.title('Survived VS Sex')
plt.show()

# %%
sns.countplot(data=data, x='Pclass', hue='Survived')
plt.title('Survival by Passenger Class')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data, x='Age', hue='Survived', multiple='stack', bins=30)
plt.title('Age Distribution by Survival')
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=data, x='Fare', hue='Survived', multiple='stack', bins=40)
plt.title('Fare Distribution by Survival')
plt.xlabel('Fare')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
